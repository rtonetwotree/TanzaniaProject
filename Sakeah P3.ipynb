# %%
import pandas as pd

training_lables = pd.read_csv("Pump_it_Up_Data_Mining_the_Water_Table_-_Training_set_labels.csv")
training_cols = pd.read_csv("Pump_it_Up_Data_Mining_the_Water_Table_-_Training_set_values.csv")

# %%
training_cols.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... payment_type  \
# 0  34.938093  -9.856322                  none            0  ...     annually
# 1  34.698766  -2.147466              Zahanati            0  ...    never pay
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...   per bucket
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...    never pay
# 4  31.130847  -1.825359               Shuleni            0  ...    never pay
#
# ...

# %%
training_lables.head()
# Out:
#       id    status_group
# 0  69572      functional
# 1   8776      functional
# 2  34310      functional
# 3  67743  non functional
# 4  19728      functional

# %%
df = pd.merge(training_cols, training_lables, on="id")

# %%
df.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... water_quality  \
# 0  34.938093  -9.856322                  none            0  ...          soft
# 1  34.698766  -2.147466              Zahanati            0  ...          soft
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...          soft
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...          soft
# 4  31.130847  -1.825359               Shuleni            0  ...          soft
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59400 entries, 0 to 59399
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     59400 non-null  int64
#  1   amount_tsh             59400 non-null  float64
#  2   date_recorded          59400 non-null  object
#  3   funder                 55765 non-null  object
#  4   gps_height             59400 non-null  int64
#  5   installer              55745 non-null  object
#  6   longitude              59400 non-null  float64
#  7   latitude               59400 non-null  float64
#  8   wpt_name               59400 non-null  object
#  9   num_private            59400 non-null  int64
#  10  basin                  59400 non-null  object
#  11  subvillage             59029 non-null  object
#  12  region                 59400 non-null  object
#  13  region_code            59400 non-null  int64
# ...

# %%
df.select_dtypes(include=['object']).nunique()
# Out:
# date_recorded              356
# funder                    1897
# installer                 2145
# wpt_name                 37400
# basin                        9
# subvillage               19287
# region                      21
# lga                        125
# ward                      2092
# public_meeting               2
# recorded_by                  1
# scheme_management           12
# scheme_name               2696
# permit                       2
# extraction_type             18
# extraction_type_group       13
# extraction_type_class        7
# management                  12
# management_group             5
# payment                      7
# payment_type                 7
# water_quality                8
# quality_group                6
# quantity                     5
# quantity_group               5
# source                      10
# source_type                  7
# source_class                 3
# waterpoint_type              7
# waterpoint_type_group        6
# ...

# %%
df.drop(['wpt_name', 'subvillage'], inplace=True, axis=1)

# %%
df[["date_recorded", "funder", "installer", "lga", "ward", "scheme_name"]]
# Out:
#       date_recorded           funder     installer             lga  \
# 0        2011-03-14            Roman         Roman          Ludewa
# 1        2013-03-06          Grumeti       GRUMETI       Serengeti
# 2        2013-02-25     Lottery Club  World vision       Simanjiro
# 3        2013-01-28           Unicef        UNICEF        Nanyumbu
# 4        2011-07-13      Action In A       Artisan         Karagwe
# ...             ...              ...           ...             ...
# 59395    2013-05-03  Germany Republi           CES             Hai
# 59396    2011-05-07      Cefa-njombe          Cefa          Njombe
# 59397    2011-04-11              NaN           NaN         Mbarali
# 59398    2011-03-08            Malec          Musa        Chamwino
# 59399    2011-03-23       World Bank         World  Morogoro Rural
#
#                    ward                  scheme_name
# 0              Mundindi                        Roman
# 1                 Natta                          NaN
# ...

# %%
df.drop([ "funder", "installer", "lga", "ward", "amount_tsh", "gps_height", "longitude", "latitude", "num_private", "quantity_group", "quality_group", "region_code", "scheme_name"], inplace=True, axis=1)

# %%
df['date_recorded'] = pd.to_datetime(df['date_recorded'], infer_datetime_format=True)

# %%
df.head()
# Out:
#       id date_recorded                    basin   region  district_code  \
# 0  69572    2011-03-14               Lake Nyasa   Iringa              5
# 1   8776    2013-03-06            Lake Victoria     Mara              2
# 2  34310    2013-02-25                  Pangani  Manyara              4
# 3  67743    2013-01-28  Ruvuma / Southern Coast   Mtwara             63
# 4  19728    2011-07-13            Lake Victoria   Kagera              1
#
#    population public_meeting              recorded_by scheme_management  \
# 0         109           True  GeoData Consultants Ltd               VWC
# 1         280            NaN  GeoData Consultants Ltd             Other
# 2         250           True  GeoData Consultants Ltd               VWC
# 3          58           True  GeoData Consultants Ltd               VWC
# 4           0           True  GeoData Consultants Ltd               NaN
#
#   permit  ...  water_quality quality_group      quantity quantity_group  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59400 entries, 0 to 59399
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     59400 non-null  int64
#  1   date_recorded          59400 non-null  datetime64[ns]
#  2   basin                  59400 non-null  object
#  3   region                 59400 non-null  object
#  4   district_code          59400 non-null  int64
#  5   population             59400 non-null  int64
#  6   public_meeting         56066 non-null  object
#  7   recorded_by            59400 non-null  object
#  8   scheme_management      55523 non-null  object
#  9   permit                 56344 non-null  object
#  10  construction_year      59400 non-null  int64
#  11  extraction_type        59400 non-null  object
#  12  extraction_type_group  59400 non-null  object
#  13  extraction_type_class  59400 non-null  object
# ...

# %%
df["date_recorded_year"]=2024-df["date_recorded"].dt.year

# %%
df.drop([ "date_recorded"], inplace=True, axis=1)

# %%
(df.isnull().sum() / df.shape[0])*100
# Out:
# id                       0.000000
# amount_tsh               0.000000
# gps_height               0.000000
# longitude                0.000000
# latitude                 0.000000
# num_private              0.000000
# basin                    0.000000
# region                   0.000000
# region_code              0.000000
# district_code            0.000000
# population               0.000000
# public_meeting           5.612795
# recorded_by              0.000000
# scheme_management        6.526936
# permit                   5.144781
# construction_year        0.000000
# extraction_type          0.000000
# extraction_type_group    0.000000
# extraction_type_class    0.000000
# management               0.000000
# management_group         0.000000
# payment                  0.000000
# payment_type             0.000000
# water_quality            0.000000
# quality_group            0.000000
# quantity                 0.000000
# quantity_group           0.000000
# ...

# %%
df[["scheme_management", "permit", "public_meeting"]]
# Out:
#       scheme_management permit public_meeting
# 0                   VWC  False           True
# 1                 Other   True            NaN
# 2                   VWC   True           True
# 3                   VWC   True           True
# 4                   NaN   True           True
# ...                 ...    ...            ...
# 59395       Water Board   True           True
# 59396               VWC   True           True
# 59397               VWC  False           True
# 59398               VWC   True           True
# 59399               VWC   True           True
#
# [59400 rows x 3 columns]

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (49841, 34)

# %%
target = df['status_group']
df.drop([ "status_group"], inplace=True, axis=1)

# %%
df = pd.get_dummies(df, drop_first = True)
df
# Out:
#           id  amount_tsh  gps_height  longitude   latitude  num_private  \
# 0      69572      6000.0        1390  34.938093  -9.856322            0
# 2      34310        25.0         686  37.460664  -3.821329            0
# 3      67743         0.0         263  38.486161 -11.155298            0
# 5       9944        20.0           0  39.172796  -4.765587            0
# 6      19816         0.0           0  33.362410  -3.766365            0
# ...      ...         ...         ...        ...        ...          ...
# 59395  60739        10.0        1210  37.169807  -3.253847            0
# 59396  27263      4700.0        1212  35.249991  -9.070629            0
# 59397  37057         0.0           0  34.017087  -8.750434            0
# 59398  31282         0.0           0  35.861315  -6.378573            0
# 59399  26348         0.0         191  38.104048  -6.747464            0
#
#        region_code  district_code  population  construction_year  ...  \
# ...
